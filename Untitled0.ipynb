# %% [markdown]
# ### Construct flowcharts to develop a calculator which converts time, distance, area, volume and temperature from one unit to another.

# %% [markdown]
# ### Construct flowcharts with separate procedures to calculate simple and compound interest for various parameters specified by the user

# %% [markdown]
# ### calculate the greatest common divisor using iteration and recursion for two numbers as specified by the user

# %% [markdown]
# ### Design a flowchart to perform Linear search on list of N unsorted numbers(Iterative and recursive)

# %% [markdown]
# ### Design a flowchart to perform Binary search on list of N sorted numbers(Iterative and recursive)

# %% [markdown]
# ### Design a flowchart to determine the number of characters and lines in a text file specified by the user
